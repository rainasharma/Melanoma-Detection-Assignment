# %% [markdown]
# Problem statement: To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %% [markdown]
# ### Importing Skin Cancer Data
# ####  Take necessary actions to read the data

# %% [markdown]
# ### Importing all the important libraries

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
from glob import glob

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# This assignment uses a dataset of about 2357 images of skin cancer types. The dataset contains 9 sub-directories in each train and test subdirectories. The 9 sub-directories contains the images of 9 skin cancer types respectively.

# %%
# Defining the path for train and test images
data_dir_train = pathlib.Path("/content/gdrive/My Drive/app/Skin cancer ISIC The International Skin Imaging Collaboration/Train")
data_dir_test = pathlib.Path('/content/gdrive/My Drive/app/Skin cancer ISIC The International Skin Imaging Collaboration/Test')

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %% [markdown]
# ### Load using keras.preprocessing
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.

# %% [markdown]
# ### Create a dataset
#
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
## Write your train dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
            data_dir_train,
            color_mode='rgb',
            batch_size=batch_size,
            image_size=(img_height, img_width),
            seed=123,
            validation_split=0.2,
            subset='training'
            )
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.

# %%
## Write your validation dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
val_ds = tf.keras.utils.image_dataset_from_directory(
            data_dir_train,
            color_mode='rgb',
            batch_size=batch_size,
            image_size=(img_height, img_width),
            seed=123,
            validation_split=0.2,
            subset='validation'
            )
# Out:
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.

# %%
# List out all the classes of skin cancer and store them in a list. 
# You can find the class names in the class_names attribute on these datasets. 
# These correspond to the directory names in alphabetical order.
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# ### Visualize the data
# #### create a code to visualize one instance of all the nine classes present in the dataset

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
for i in range(9): 
  plt.subplot(3, 3, i + 1)
  image = plt.imread(str(list(data_dir_train.glob(class_names[i]+'/*.jpg'))[1]))
  plt.title(class_names[i])
  plt.imshow(image)

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# # M1 model

# %% [markdown]
# ### Create the model
# #### Create a CNN model, which can accurately detect 9 classes present in the dataset. Use ```layers.experimental.preprocessing.Rescaling``` to normalize pixel values between (0,1). The RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network. Here, it is good to standardize values to be in the `[0, 1]`

# %%
num_class = 9
model = Sequential([
    layers.Rescaling(scale = 1./255, input_shape = (img_height,img_width,3)),
    layers.Conv2D(16,3,padding='same',activation= 'relu'),
    layers.MaxPool2D((2,2),strides=2),
    layers.Conv2D(32,3,padding='same',activation= 'relu'),
    layers.MaxPool2D((2,2),strides=2),
    layers.Conv2D(64,3,padding='same',activation= 'relu'),
    layers.MaxPool2D((2,2),strides=2),
    layers.Flatten(),
    layers.Dense(128,activation='relu'),
    layers.Dense(num_class)
])

# %% [markdown]
# ### Compile the model
# Choose an appropirate optimiser and loss function for model training

# %%
### choose an appropirate optimiser and loss function
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 90, 90, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 90, 90, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 45, 45, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 45, 45, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 22, 22, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 30976)             0
#
#  dense (Dense)               (None, 128)               3965056
#
#  dense_1 (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 3,989,801
# Trainable params: 3,989,801
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
epochs = 30
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/30
# 56/56 [==============================] - 161s 544ms/step - loss: 2.0312 - accuracy: 0.2506 - val_loss: 2.2117 - val_accuracy: 0.1924
# Epoch 2/30
# 56/56 [==============================] - 1s 25ms/step - loss: 1.8067 - accuracy: 0.3410 - val_loss: 1.6370 - val_accuracy: 0.4049
# Epoch 3/30
# 56/56 [==============================] - 1s 23ms/step - loss: 1.5686 - accuracy: 0.4492 - val_loss: 1.6338 - val_accuracy: 0.4564
# Epoch 4/30
# 56/56 [==============================] - 1s 23ms/step - loss: 1.4140 - accuracy: 0.5011 - val_loss: 1.5423 - val_accuracy: 0.4765
# Epoch 5/30
# 56/56 [==============================] - 1s 23ms/step - loss: 1.3152 - accuracy: 0.5491 - val_loss: 1.6133 - val_accuracy: 0.4720
# Epoch 6/30
# 56/56 [==============================] - 1s 23ms/step - loss: 1.2661 - accuracy: 0.5508 - val_loss: 1.4474 - val_accuracy: 0.5257
# Epoch 7/30
# 56/56 [==============================] - 1s 23ms/step - loss: 1.1841 - accuracy: 0.5804 - val_loss: 1.4171 - val_accuracy: 0.5347
# Epoch 8/30
# 56/56 [==============================] - 1s 23ms/step - loss: 1.1248 - accuracy: 0.6004 - val_loss: 1.4403 - val_accuracy: 0.5324
# Epoch 9/30
# 56/56 [==============================] - 1s 23ms/step - loss: 1.0154 - accuracy: 0.6384 - val_loss: 1.4569 - val_accuracy: 0.5168
# Epoch 10/30
# 56/56 [==============================] - 1s 24ms/step - loss: 0.9423 - accuracy: 0.6674 - val_loss: 1.5504 - val_accuracy: 0.5481
# Epoch 11/30
# 56/56 [==============================] - 1s 23ms/step - loss: 0.9511 - accuracy: 0.6607 - val_loss: 1.5602 - val_accuracy: 0.5034
# Epoch 12/30
# 56/56 [==============================] - 1s 23ms/step - loss: 0.8623 - accuracy: 0.6881 - val_loss: 1.5698 - val_accuracy: 0.5011
# Epoch 13/30
# 56/56 [==============================] - 1s 23ms/step - loss: 0.8130 - accuracy: 0.7215 - val_loss: 1.6612 - val_accuracy: 0.4989
# Epoch 14/30
# 56/56 [==============================] - 1s 23ms/step - loss: 0.6593 - accuracy: 0.7667 - val_loss: 1.6720 - val_accuracy: 0.5123
# Epoch 15/30
# 56/56 [==============================] - 1s 23ms/step - loss: 0.6259 - accuracy: 0.7740 - val_loss: 1.6294 - val_accuracy: 0.5280
# Epoch 16/30
# 56/56 [==============================] - 1s 23ms/step - loss: 0.5877 - accuracy: 0.7835 - val_loss: 1.7818 - val_accuracy: 0.4877
# Epoch 17/30
# 56/56 [==============================] - 1s 23ms/step - loss: 0.5206 - accuracy: 0.8114 - val_loss: 2.0378 - val_accuracy: 0.5235
# Epoch 18/30
# 56/56 [==============================] - 1s 23ms/step - loss: 0.4300 - accuracy: 0.8393 - val_loss: 1.8766 - val_accuracy: 0.5503
# Epoch 19/30
# 56/56 [==============================] - 1s 23ms/step - loss: 0.3736 - accuracy: 0.8627 - val_loss: 2.1662 - val_accuracy: 0.5280
# Epoch 20/30
# 56/56 [==============================] - 1s 24ms/step - loss: 0.3806 - accuracy: 0.8560 - val_loss: 2.0500 - val_accuracy: 0.4989
# Epoch 21/30
# 56/56 [==============================] - 1s 23ms/step - loss: 0.3178 - accuracy: 0.8744 - val_loss: 2.1912 - val_accuracy: 0.5481
# Epoch 22/30
# 56/56 [==============================] - 1s 23ms/step - loss: 0.2947 - accuracy: 0.8940 - val_loss: 2.2945 - val_accuracy: 0.5324
# Epoch 23/30
# 56/56 [==============================] - 1s 24ms/step - loss: 0.2776 - accuracy: 0.8968 - val_loss: 2.1534 - val_accuracy: 0.5414
# Epoch 24/30
# 56/56 [==============================] - 1s 23ms/step - loss: 0.2497 - accuracy: 0.9040 - val_loss: 2.5003 - val_accuracy: 0.5369
# Epoch 25/30
# 56/56 [==============================] - 1s 23ms/step - loss: 0.2154 - accuracy: 0.9124 - val_loss: 2.4912 - val_accuracy: 0.5280
# Epoch 26/30
# 56/56 [==============================] - 1s 23ms/step - loss: 0.2187 - accuracy: 0.9219 - val_loss: 2.2738 - val_accuracy: 0.5190
# Epoch 27/30
# 56/56 [==============================] - 1s 23ms/step - loss: 0.1738 - accuracy: 0.9286 - val_loss: 2.4457 - val_accuracy: 0.5503
# Epoch 28/30
# 56/56 [==============================] - 1s 23ms/step - loss: 0.2128 - accuracy: 0.9129 - val_loss: 2.4742 - val_accuracy: 0.5503
# Epoch 29/30
# 56/56 [==============================] - 1s 23ms/step - loss: 0.1805 - accuracy: 0.9230 - val_loss: 2.3502 - val_accuracy: 0.5324
# Epoch 30/30
# 56/56 [==============================] - 1s 23ms/step - loss: 0.1681 - accuracy: 0.9297 - val_loss: 2.2994 - val_accuracy: 0.5414

# %% [markdown]
# ### Visualizing training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ### Observations
#
# ANS: The model is overfitting because the accuracy on train dataset is quite high 0.927 while on the validation set is quite low i.e. 0.54.
#
# There is also difference in loss functions in training & test. For training data set it is decreasing while for validation data set it is increasing.

# %% [markdown]
# # M2 model

# %%
#  As the model is overfit, lets apply data augumentation strategy. 
data_augument = keras.Sequential([
                             layers.experimental.preprocessing.RandomFlip(mode="horizontal_and_vertical",input_shape=(img_height,img_width,3)),
                             layers.experimental.preprocessing.RandomRotation(0.2, fill_mode='reflect'),
                             layers.experimental.preprocessing.RandomZoom(height_factor=(0.2, 0.3), width_factor=(0.2, 0.3), fill_mode='reflect')
])

# %%
#  visualize how your augmentation strategy works for one instance of training image.
# Your code goes here
plt.figure(figsize=(12, 12))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(data_augument(images)[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %% [markdown]
# ### Create the model, compile and train the model

# %%
## Using Dropiut layer as the model is overfitting.
num_class = 9
model = Sequential([
  data_augument,
  layers.Rescaling(1./255, input_shape=(img_height, img_width,3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPool2D((2,2),strides=2),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPool2D((2,2),strides=2),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPool2D((2,2),strides=2),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_class)
])

# %% [markdown]
# ### Compiling the model

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_1 (Sequential)   (None, 180, 180, 3)       0
#
#  rescaling_1 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_3 (Conv2D)           (None, 180, 180, 16)      448
#
#  max_pooling2d_3 (MaxPooling  (None, 90, 90, 16)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 90, 90, 32)        4640
#
#  max_pooling2d_4 (MaxPooling  (None, 45, 45, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 45, 45, 64)        18496
#
#  max_pooling2d_5 (MaxPooling  (None, 22, 22, 64)       0
#  2D)
#
#  dropout (Dropout)           (None, 22, 22, 64)        0
#
#  flatten_1 (Flatten)         (None, 30976)             0
#
#  dense_2 (Dense)             (None, 128)               3965056
#
#  dense_3 (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 3,989,801
# Trainable params: 3,989,801
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Training the model

# %%
## Your code goes here, note: train your model for 20 epochs
epochs = 30
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/30
# 56/56 [==============================] - 3s 30ms/step - loss: 1.9549 - accuracy: 0.2963 - val_loss: 1.6802 - val_accuracy: 0.3982
# Epoch 2/30
# 56/56 [==============================] - 1s 26ms/step - loss: 1.6148 - accuracy: 0.4325 - val_loss: 1.4852 - val_accuracy: 0.5056
# Epoch 3/30
# 56/56 [==============================] - 1s 26ms/step - loss: 1.4603 - accuracy: 0.4754 - val_loss: 1.4786 - val_accuracy: 0.5078
# Epoch 4/30
# 56/56 [==============================] - 1s 26ms/step - loss: 1.3969 - accuracy: 0.5151 - val_loss: 1.4184 - val_accuracy: 0.5235
# Epoch 5/30
# 56/56 [==============================] - 1s 27ms/step - loss: 1.3318 - accuracy: 0.5307 - val_loss: 1.3931 - val_accuracy: 0.5503
# Epoch 6/30
# 56/56 [==============================] - 1s 26ms/step - loss: 1.3227 - accuracy: 0.5296 - val_loss: 1.4086 - val_accuracy: 0.5324
# Epoch 7/30
# 56/56 [==============================] - 1s 27ms/step - loss: 1.3096 - accuracy: 0.5262 - val_loss: 1.4012 - val_accuracy: 0.5213
# Epoch 8/30
# 56/56 [==============================] - 1s 26ms/step - loss: 1.2770 - accuracy: 0.5435 - val_loss: 1.4029 - val_accuracy: 0.4922
# Epoch 9/30
# 56/56 [==============================] - 1s 26ms/step - loss: 1.2532 - accuracy: 0.5430 - val_loss: 1.4574 - val_accuracy: 0.4899
# Epoch 10/30
# 56/56 [==============================] - 1s 26ms/step - loss: 1.2532 - accuracy: 0.5458 - val_loss: 1.3987 - val_accuracy: 0.5168
# Epoch 11/30
# 56/56 [==============================] - 1s 27ms/step - loss: 1.2153 - accuracy: 0.5513 - val_loss: 1.3811 - val_accuracy: 0.5414
# Epoch 12/30
# 56/56 [==============================] - 1s 26ms/step - loss: 1.2146 - accuracy: 0.5608 - val_loss: 1.4287 - val_accuracy: 0.4855
# Epoch 13/30
# 56/56 [==============================] - 1s 27ms/step - loss: 1.1968 - accuracy: 0.5580 - val_loss: 1.3337 - val_accuracy: 0.5190
# Epoch 14/30
# 56/56 [==============================] - 1s 27ms/step - loss: 1.1605 - accuracy: 0.5815 - val_loss: 1.3670 - val_accuracy: 0.5570
# Epoch 15/30
# 56/56 [==============================] - 1s 26ms/step - loss: 1.1591 - accuracy: 0.5893 - val_loss: 1.3136 - val_accuracy: 0.5503
# Epoch 16/30
# 56/56 [==============================] - 1s 26ms/step - loss: 1.1688 - accuracy: 0.5753 - val_loss: 1.3819 - val_accuracy: 0.5615
# Epoch 17/30
# 56/56 [==============================] - 1s 27ms/step - loss: 1.1461 - accuracy: 0.5865 - val_loss: 1.4520 - val_accuracy: 0.5414
# Epoch 18/30
# 56/56 [==============================] - 1s 26ms/step - loss: 1.1441 - accuracy: 0.5910 - val_loss: 1.3826 - val_accuracy: 0.5459
# Epoch 19/30
# 56/56 [==============================] - 1s 27ms/step - loss: 1.0979 - accuracy: 0.5921 - val_loss: 1.3571 - val_accuracy: 0.5503
# Epoch 20/30
# 56/56 [==============================] - 1s 26ms/step - loss: 1.0913 - accuracy: 0.6004 - val_loss: 1.3953 - val_accuracy: 0.5548
# Epoch 21/30
# 56/56 [==============================] - 1s 26ms/step - loss: 1.0773 - accuracy: 0.6044 - val_loss: 1.3637 - val_accuracy: 0.5347
# Epoch 22/30
# 56/56 [==============================] - 1s 26ms/step - loss: 1.0722 - accuracy: 0.6055 - val_loss: 1.2832 - val_accuracy: 0.5749
# Epoch 23/30
# 56/56 [==============================] - 1s 26ms/step - loss: 1.0548 - accuracy: 0.6150 - val_loss: 1.4801 - val_accuracy: 0.4989
# Epoch 24/30
# 56/56 [==============================] - 1s 26ms/step - loss: 1.1324 - accuracy: 0.5809 - val_loss: 1.4327 - val_accuracy: 0.5548
# Epoch 25/30
# 56/56 [==============================] - 1s 27ms/step - loss: 1.0577 - accuracy: 0.6200 - val_loss: 1.4935 - val_accuracy: 0.5145
# Epoch 26/30
# 56/56 [==============================] - 1s 26ms/step - loss: 1.0353 - accuracy: 0.6155 - val_loss: 1.3941 - val_accuracy: 0.5190
# Epoch 27/30
# 56/56 [==============================] - 1s 27ms/step - loss: 1.0556 - accuracy: 0.6055 - val_loss: 1.5286 - val_accuracy: 0.5235
# Epoch 28/30
# 56/56 [==============================] - 1s 26ms/step - loss: 1.0830 - accuracy: 0.6088 - val_loss: 1.6834 - val_accuracy: 0.4966
# Epoch 29/30
# 56/56 [==============================] - 1s 26ms/step - loss: 1.0608 - accuracy: 0.6122 - val_loss: 1.3804 - val_accuracy: 0.5570
# Epoch 30/30
# 56/56 [==============================] - 1s 27ms/step - loss: 1.0294 - accuracy: 0.6172 - val_loss: 1.4444 - val_accuracy: 0.5481

# %% [markdown]
# ### Visualizing the results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# **Finding from Second Model**
#
# - There is no improvement in accuracy, however it decreased but we can definitely see the overfitting problem has solved due to data augmentation
#
# - We can increase the epochs or can add dropouts to other layers to increase the accuracy

# %% [markdown]
# ####  Find the distribution of classes in the training dataset.
# #### **Context:** Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
## Your code goes here.
## original_df - > path_list, lesion_list
path_list=[]
lesion_list=[]
for i in class_names:
    for j in data_dir_train.glob(i+'/*.jpg'):
        path_list.append(str(j))
        lesion_list.append(i)
dataframe_dict_original = dict(zip(path_list, lesion_list))
original_df = pd.DataFrame(list(dataframe_dict_original.items()),columns = ['Path','Label'])
original_df
# Out:
#                                                    Path              Label
# 0     /content/gdrive/My Drive/app/Skin cancer ISIC ...  actinic keratosis
# 1     /content/gdrive/My Drive/app/Skin cancer ISIC ...  actinic keratosis
# 2     /content/gdrive/My Drive/app/Skin cancer ISIC ...  actinic keratosis
# 3     /content/gdrive/My Drive/app/Skin cancer ISIC ...  actinic keratosis
# 4     /content/gdrive/My Drive/app/Skin cancer ISIC ...  actinic keratosis
# ...                                                 ...                ...
# 2234  /content/gdrive/My Drive/app/Skin cancer ISIC ...    vascular lesion
# 2235  /content/gdrive/My Drive/app/Skin cancer ISIC ...    vascular lesion
# 2236  /content/gdrive/My Drive/app/Skin cancer ISIC ...    vascular lesion
# 2237  /content/gdrive/My Drive/app/Skin cancer ISIC ...    vascular lesion
# 2238  /content/gdrive/My Drive/app/Skin cancer ISIC ...    vascular lesion
#
# [2239 rows x 2 columns]

# %%
original_df['Label'].value_counts()
# Out:
# pigmented benign keratosis    462
# melanoma                      438
# basal cell carcinoma          376
# nevus                         357
# squamous cell carcinoma       181
# vascular lesion               139
# actinic keratosis             114
# dermatofibroma                 95
# seborrheic keratosis           77
# Name: Label, dtype: int64

# %%
count=[]
for i in class_names:
    count.append(len(list(data_dir_train.glob(i+'/*.jpg'))))
plt.figure(figsize=(25,10))
plt.bar(class_names,count)
# Out:
# <BarContainer object of 9 artists>

# %% [markdown]
# #### Write your findings here:
# #### - Which class has the least number of samples?
# #### - Which classes dominate the data in terms proportionate number of samples?

# %% [markdown]
# Answer-1 :- **seborrheic keratosis** has least number of samples
#
# Answer-2:- **actinic keratosis and dermatofibroma** have proportionate number of classes.
# **melanoma and pigmented benign keratosis** have proprtionate number of classes
# - **pigmented benign keratosis** have highest number of samples.

# %% [markdown]
# #### Rectify the class imbalance
# #### **Context:** You can use a python package known as `Augmentor` (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %%
# !pip install Augmentor
# Out:
# Collecting Augmentor
#   Downloading Augmentor-0.2.9-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (4.64.0)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (1.21.6)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (7.1.2)
# Requirement already satisfied: future>=0.16.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (0.16.0)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.9

# %% [markdown]
# To use `Augmentor`, the following general procedure is followed:
#
# 1. Instantiate a `Pipeline` object pointing to a directory containing your initial image data set.<br>
# 2. Define a number of operations to perform on this data set using your `Pipeline` object.<br>
# 3. Execute these operations by calling the `Pipeline’s` `sample()` method.

# %%
path_to_training_dataset="/content/gdrive/My Drive/app/Skin cancer ISIC The International Skin Imaging Collaboration/Train/"
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset+i,save_format='jpg')
    p.rotate(probability = 0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.
# Out:
# Initialised with 114 image(s) found.
# Output directory set to /content/gdrive/My Drive/app/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7FE6B848CB90>: 100%|██████████| 500/500 [00:22<00:00, 22.08 Samples/s]
# Initialised with 376 image(s) found.
# Output directory set to /content/gdrive/My Drive/app/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FE6B9013150>: 100%|██████████| 500/500 [00:21<00:00, 23.19 Samples/s]
# Initialised with 95 image(s) found.
# Output directory set to /content/gdrive/My Drive/app/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FE6B8493590>: 100%|██████████| 500/500 [00:22<00:00, 22.20 Samples/s]
# Initialised with 438 image(s) found.
# Output directory set to /content/gdrive/My Drive/app/Skin cancer ISIC The International Skin Imaging Collaboration/Train/melanoma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x768 at 0x7FE6B8468710>: 100%|██████████| 500/500 [01:32<00:00,  5.40 Samples/s]
# Initialised with 357 image(s) found.
# Output directory set to /content/gdrive/My Drive/app/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output.
# Processing <PIL.Image.Image image mode=RGB size=1011x713 at 0x7FE6B852D850>: 100%|██████████| 500/500 [01:32<00:00,  5.40 Samples/s]
# Initialised with 462 image(s) found.
# Output directory set to /content/gdrive/My Drive/app/Skin cancer ISIC The International Skin Imaging Collaboration/Train/pigmented benign keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FE6B83B6050>: 100%|██████████| 500/500 [00:20<00:00, 24.63 Samples/s]
# Initialised with 77 image(s) found.
# Output directory set to /content/gdrive/My Drive/app/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FE6B96CBB90>: 100%|██████████| 500/500 [00:44<00:00, 11.35 Samples/s]
# Initialised with 181 image(s) found.
# Output directory set to /content/gdrive/My Drive/app/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7FE6B9034B90>: 100%|██████████| 500/500 [00:18<00:00, 27.17 Samples/s]
# Initialised with 139 image(s) found.
# Output directory set to /content/gdrive/My Drive/app/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FE6B9086CD0>: 100%|██████████| 500/500 [00:18<00:00, 26.38 Samples/s]

# %% [markdown]
# Augmentor has stored the augmented images in the output sub-directory of each of the sub-directories of skin cancer types.. Lets take a look at total count of augmented images.

# %%
image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)
# Out:
# 4500

# %% [markdown]
# ### Lets see the distribution of augmented data after adding new images to the original training data.

# %%
path_list = [x for x in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]

# %%
lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]

# %%
dataframe_dict_new = dict(zip(path_list, lesion_list_new))

# %%
df2 = pd.DataFrame(list(dataframe_dict_new.items()),columns = ['Path','Label'])
new_df = df2

# %%
new_df['Label'].value_counts()
# Out:
# melanoma                      500
# nevus                         500
# seborrheic keratosis          500
# actinic keratosis             500
# dermatofibroma                500
# basal cell carcinoma          500
# vascular lesion               500
# squamous cell carcinoma       500
# pigmented benign keratosis    500
# Name: Label, dtype: int64

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# # M3 Model

# %% [markdown]
# ####  Train the model on the data created using Augmentor

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# ####  Create a training dataset

# %%
data_dir_train=pathlib.Path("/content/gdrive/My Drive/app/Skin cancer ISIC The International Skin Imaging Collaboration/Train")
train_ds_new = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'training',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 5392 files for training.

# %% [markdown]
# ####  Create a validation dataset

# %%
val_ds_new = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'validation',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 1347 files for validation.

# %% [markdown]
# #### Create your model (make sure to include normalization)

# %%
num_classes = len(class_names)

model = Sequential([
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.BatchNormalization(),
  layers.Dropout(0.25),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.BatchNormalization(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.25),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %% [markdown]
# #### Compile your model (Choose optimizer and loss function appropriately)

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# ####  Train your model

# %%
epochs = 30
history = model.fit(
  train_ds_new,
  validation_data=val_ds_new,
  epochs=epochs
)
# Out:
# Epoch 1/30
# 169/169 [==============================] - 33s 177ms/step - loss: 2.5659 - accuracy: 0.3325 - val_loss: 2.4147 - val_accuracy: 0.1841
# Epoch 2/30
# 169/169 [==============================] - 30s 170ms/step - loss: 1.4498 - accuracy: 0.4447 - val_loss: 2.2979 - val_accuracy: 0.1425
# Epoch 3/30
# 169/169 [==============================] - 30s 170ms/step - loss: 1.2342 - accuracy: 0.5352 - val_loss: 1.6251 - val_accuracy: 0.3734
# Epoch 4/30
# 169/169 [==============================] - 30s 173ms/step - loss: 1.0630 - accuracy: 0.5989 - val_loss: 1.2092 - val_accuracy: 0.5494
# Epoch 5/30
# 169/169 [==============================] - 30s 171ms/step - loss: 0.8910 - accuracy: 0.6741 - val_loss: 1.0505 - val_accuracy: 0.6340
# Epoch 6/30
# 169/169 [==============================] - 30s 170ms/step - loss: 0.7458 - accuracy: 0.7272 - val_loss: 2.2374 - val_accuracy: 0.4232
# Epoch 7/30
# 169/169 [==============================] - 30s 170ms/step - loss: 0.6383 - accuracy: 0.7685 - val_loss: 1.1437 - val_accuracy: 0.6021
# Epoch 8/30
# 169/169 [==============================] - 30s 172ms/step - loss: 0.5685 - accuracy: 0.7936 - val_loss: 1.4519 - val_accuracy: 0.5724
# Epoch 9/30
# 169/169 [==============================] - 30s 170ms/step - loss: 0.4993 - accuracy: 0.8097 - val_loss: 1.3994 - val_accuracy: 0.6013
# Epoch 10/30
# 169/169 [==============================] - 30s 172ms/step - loss: 0.4246 - accuracy: 0.8405 - val_loss: 1.1284 - val_accuracy: 0.6496
# Epoch 11/30
# 169/169 [==============================] - 30s 172ms/step - loss: 0.3943 - accuracy: 0.8481 - val_loss: 1.1481 - val_accuracy: 0.6607
# Epoch 12/30
# 169/169 [==============================] - 30s 172ms/step - loss: 0.3330 - accuracy: 0.8739 - val_loss: 1.2689 - val_accuracy: 0.6377
# Epoch 13/30
# 169/169 [==============================] - 30s 171ms/step - loss: 0.3210 - accuracy: 0.8828 - val_loss: 1.0247 - val_accuracy: 0.6889
# Epoch 14/30
# 169/169 [==============================] - 30s 171ms/step - loss: 0.3085 - accuracy: 0.8828 - val_loss: 0.8591 - val_accuracy: 0.7476
# Epoch 15/30
# 169/169 [==============================] - 30s 171ms/step - loss: 0.2662 - accuracy: 0.8941 - val_loss: 0.9314 - val_accuracy: 0.7476
# Epoch 16/30
# 169/169 [==============================] - 30s 174ms/step - loss: 0.2410 - accuracy: 0.9076 - val_loss: 0.9797 - val_accuracy: 0.7379
# Epoch 17/30
# 169/169 [==============================] - 30s 173ms/step - loss: 0.2620 - accuracy: 0.9037 - val_loss: 1.0860 - val_accuracy: 0.6875
# Epoch 18/30
# 169/169 [==============================] - 30s 173ms/step - loss: 0.2327 - accuracy: 0.9123 - val_loss: 1.0378 - val_accuracy: 0.7342
# Epoch 19/30
# 169/169 [==============================] - 30s 171ms/step - loss: 0.2440 - accuracy: 0.9052 - val_loss: 0.9000 - val_accuracy: 0.7520
# Epoch 20/30
# 169/169 [==============================] - 30s 171ms/step - loss: 0.2009 - accuracy: 0.9232 - val_loss: 1.9719 - val_accuracy: 0.5857
# Epoch 21/30
# 169/169 [==============================] - 30s 172ms/step - loss: 0.1930 - accuracy: 0.9258 - val_loss: 0.8317 - val_accuracy: 0.7899
# Epoch 22/30
# 169/169 [==============================] - 30s 172ms/step - loss: 0.1744 - accuracy: 0.9329 - val_loss: 1.1178 - val_accuracy: 0.7112
# Epoch 23/30
# 169/169 [==============================] - 30s 172ms/step - loss: 0.1506 - accuracy: 0.9421 - val_loss: 0.8933 - val_accuracy: 0.7877
# Epoch 24/30
# 169/169 [==============================] - 30s 174ms/step - loss: 0.1788 - accuracy: 0.9323 - val_loss: 1.0135 - val_accuracy: 0.7535
# Epoch 25/30
# 169/169 [==============================] - 30s 174ms/step - loss: 0.1591 - accuracy: 0.9386 - val_loss: 2.1799 - val_accuracy: 0.5820
# Epoch 26/30
# 169/169 [==============================] - 30s 173ms/step - loss: 0.1467 - accuracy: 0.9381 - val_loss: 1.4596 - val_accuracy: 0.6956
# Epoch 27/30
# 169/169 [==============================] - 30s 172ms/step - loss: 0.1674 - accuracy: 0.9330 - val_loss: 1.0630 - val_accuracy: 0.7327
# Epoch 28/30
# 169/169 [==============================] - 30s 174ms/step - loss: 0.1933 - accuracy: 0.9280 - val_loss: 1.0400 - val_accuracy: 0.7520
# Epoch 29/30
# 169/169 [==============================] - 30s 174ms/step - loss: 0.1637 - accuracy: 0.9343 - val_loss: 0.9292 - val_accuracy: 0.7899
# Epoch 30/30
# 169/169 [==============================] - 30s 173ms/step - loss: 0.1438 - accuracy: 0.9418 - val_loss: 1.0597 - val_accuracy: 0.7654

# %% [markdown]
# #### Visualize the model results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ####  Analyze your results here. Did you get rid of underfitting/overfitting? Did class rebalance help?

# %% [markdown]
# # Now we have good train accuracy ( 93% ) and Validation Accuracy (76%)

# %% [markdown]
# Accuracy on training data has increased by using Augmentor library
#
# Model is still overfitting
#
# The problem of overfitting can be solved by add more layer,neurons or adding dropout layers.
#
# The Model can be further improved by tuning the hyperparameter

# %% [markdown]
# Analysis on Test Data

# %%
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_test,
    seed = 123,
    image_size = (img_height,img_width),
    batch_size = batch_size
)
# Out:
# Found 118 files belonging to 9 classes.

# %%
loss , accuracy = model.evaluate(test_ds)
# Out:
# 4/4 [==============================] - 12s 66ms/step - loss: 7.4742 - accuracy: 0.3983

# %%
print("Accuracy on test data ", accuracy)
# Out:
# Accuracy on test data  0.39830508828163147

# %% [markdown]
# Prediction on New Test Data

# %%
nevus_path = "/content/gdrive/MyDrive/app/Skin cancer ISIC The International Skin Imaging Collaboration/Test/nevus/ISIC_0000001.jpg"

img = tf.keras.utils.load_img(
    nevus_path, target_size=(img_height, img_width)
)
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(score)
# Out:
# tf.Tensor(
# [7.6541329e-10 7.3293620e-07 1.1390487e-14 3.4394893e-03 9.9654335e-01
#  1.1800990e-05 4.4405870e-06 1.8554411e-07 3.8520263e-08], shape=(9,), dtype=float32)

# %%
print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(test_ds.class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# This image most likely belongs to nevus with a 99.65 percent confidence.
